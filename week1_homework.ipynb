# %% [markdown]
# **Leetcode** 167

# %%
april 27th 8 min

# %% [markdown]
# Leetcode 219

# %%
april 27th buhui

# %% [markdown]
# Leetcode 242

# %%
april 27th 8 mins

# %% [markdown]
# Leetcode 268

# %%
april 27th 10 mins

# %% [markdown]
# Leetcode 349

# %%
april27th 5 min

# %% [markdown]
# Leetcode 350

# %%
april27th 15 min

# %% [markdown]
# Leetcode 389

# %%
april 27th not pass

# %% [markdown]
# Leetcode 442

# %%
april 27th 5 mins

# %% [markdown]
# Leetcode 448

# %%
april 27th 10 mins

# %% [markdown]
# Leetcode 575

# %%
april 27th 8 mins
