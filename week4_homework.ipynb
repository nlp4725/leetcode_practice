# %% [markdown]
# Leetcode 20

# %% [markdown]
# Leetcode 155

# %% [markdown]
# Leetcode 225

# %% [markdown]
# Leetcode 232

# %% [markdown]
# Leetcode 641

# %% [markdown]
# Leetcode 682

# %% [markdown]
# Leetcode 844

# %% [markdown]
# Leetcode 933

# %% [markdown]
# Leetcode 1441

# %% [markdown]
# Leetcode 496 (optional)
