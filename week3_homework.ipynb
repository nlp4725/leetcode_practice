# %% [markdown]
# Leetcode 27

# %% [markdown]
# Leetcode 125

# %% [markdown]
# Leetcode 167

# %% [markdown]
# Leetcode 344

# %% [markdown]
# Leetcode 345

# %% [markdown]
# Leetcode 905

# %% [markdown]
# Leetcode 922

# %% [markdown]
# Leetcode 977

# %% [markdown]
# Leetcode 1004 (optional)
