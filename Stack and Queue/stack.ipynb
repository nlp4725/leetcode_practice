# %% [markdown]
# # Stack vs Queue

# %% [markdown]
# Stack (LIFO)
#
# - underlying structure: **list/dynamic array**( continouse memory)
# - push = list.append(): to right/end [1,2] -> [1,2,3] **O(1)**
# - pop= list.pop(): from right/end [1,2,3] -> [1,2] **O(1)**
#
# Queue (FIFO): two ways to implement
#
# * **deque([])** official way. why? pop is fast
#   - underlying structure: **linked list** (non continouse memory)
#   - push =deque.append(): to right/end [1,2] -> [1,2,3] **O(1)**
#   - pop =deque.popleft(): from left/beginning [1,2,3] ->[2,3] **O(1)**
#
# * list: works but not recommended
#   - underlying structure: dynamic array
#   - push =list.append(): to right/end [1,2] -> [1,2,3] **O(1)**
#   - pop =list.pop(0): from left/beginning [1,2,3] ->[2,3] **O(N)**
#
#
# List/Dynamic array:
# - append 0(1)
# - pop right O(1)
# - pop left O(n) (Tradeoff shift all elements)
# - Look up O(1) (Main reason why list uses dynamic array but not linked list)
# - insert O(n) (Tradeoff shift all elements)

# %% [markdown]
# | Use Case         | Stack Example                        | Queue Example                        |
# |------------------|--------------------------------------|--------------------------------------|
# | Example 1        | Undo typing in VS Code (Ctrl+Z)      | Print jobs sent to printer           |
# | Example 2        | Browser back button history          | Customers waiting in a support line  |
# | Example 3        | Function calls in recursive programs | Messages processed in Kafka          |

# %% [markdown]
# # Leetcode 1381-Design a Stack With Increment Operation

# %% [markdown]
# Description:
#
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.
#
# Implement the `CustomStack` class:
#
# - `CustomStack(int maxSize)` Initializes the object with maxSize which is the maximum number of elements
# in the stack or do nothing if the stack reached the maxSize.
# - `void push(int x)` Adds x to the top of the stack if the stack hasn’t reached the maxSize.
#
# - `int pop()`pops and returns the top of the stack or -1 if the stack is empty.
#
# - `void inc(int k, int val)` increments the bottol of k elements of the stack by val. If there are less than k elements in the stack, increment all the elements in the stack.

# %% [markdown]
# # Thoughts
#
# Use List to implement Stack: LIFO
#
# push is append O(1)
#
# pop is pop O(1)
#
# inc bottom k elements are the oldest? O(K)
#
# inc could be O(1) using extra array (pay the debt as you pop) -> did not implement

# %%
class CustomStack():
    def __init__(self, maxSize:int)-> None:
        self._myStack=[] # initiate stack as a list
        self._size=maxSize # attribute is the max size of list
    
    def push(self,x:int) -> None:
        if len(self._myStack)< self._size: # no =
            self._myStack.append(x) # O(1) do i need to raise error if reach max

    def pop(self) -> int:
        if not self._myStack:
            return -1
        else:
            return self._myStack.pop() #O(1)

    
    def inc(self,k: int, val: int) -> None:
        # the bottom of the stacks are oldest ones, start with index 0 to k

        # if k> current length, then update k to the current length
        k=min(k,len(self._myStack))

        for i in range(k): #O(k)
            self._myStack[i]+= val

# %%
stack1=CustomStack(4)
stack1.push(1)
stack1.push(2)
print(stack1._myStack)
# Out:
# [1, 2]

# %% [markdown]
# # Leetcode 1047- Remove All Adjacent Duplicates In String

# %% [markdown]
# Description:
# Given a string S of lowercase letters, a duplicate removal consists of choosing two adjacent and equal letters, and removing them.
#
# We repeatedly make duplicate removals on S until we no longer can.
#
# Return the final string after all such duplicate removals have been made. It is guaranteed the answer is unique.
#
# Note:
# <= S.length <= 20000.
# consists only of English lowercase letters.
# Example:
# Input:"abbaca"
#
# Output:"ca"
#
# Explanation:

# %% [markdown]
# Thoughts:
#
# empty check, answer
#
# Algorithem
#
# 1. initiate stack and pointer
#
# 2. loop through s:
#
# > if stack is empty, add s[i]
#
# > if stack not empty, if s[i] == stack.top:
#
# > > if yes, pop stack.pop move pointer in string
#
# > > if no, add s[i] to stack, move poiner in string
#
# 3. return stack

# %% [markdown]
# # Thoughts 4/1/2026
#
# use stack time O(n) space O(n)
#
# algorithem:
#
# initiate a pointer i to track index at s
#
# initiate a stack/list structure to track elements
#
#
# while i<=len(s)-1:
# > check if stack is empty, if so, directly add s[i] to stack
#
# > if not emty:
#
# > > check next char at s s[i] == stack.top()([-1])
#
# > > if yes:
#  - remove stack top element
#
# > > else:
#  - add current char to stack
#
# > pointer move to next
#
# return stack

# %%
def pop_duplicates(s:str)->str:
    i = 0
    myStack=[]

    while i<=len(s)-1:
        if not myStack: # if empty, add to the stack and move the pointer
            myStack.append(s[i])
        else: # if not empty, compare
            if s[i] == myStack[-1]: # if next char in s matches stack's top,pop
                myStack.pop()
            else: # else add current char to stack
                myStack.append(s[i])
        i+= 1

    return str(''.join(myStack))

# %%
print(pop_duplicates('abbaca'))
# Out:
# ca

# %% [markdown]
# # Leetcode 20-Valid Parentheses

# %% [markdown]
# Description:
# Given a string containing just the characters "(", ")", "{", "}", "[" and "]", determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Note:
# That an empty string is also considered valid.
#
# Example1:
# Input: "( )"
#
# Output: true
#
# Example2:
# Input: "( ) [ ] { }"
#
# Output: true
#
# Example3:
# Input: "( ]"
#
# Output: false
#
# Example4:
# Input: "( [ ) ]"
#
# Output: false
#
# Example5:
# Input: "{ [ ] }"
#
# Output: true

# %% [markdown]
# # Thoughts 4/10/2026 PASS TEST
#
# empty? needs check
#
# answer? True or False. Yes, definitely has one answer
#
# Algorithm. Time O(N) Space O(N)
#
# <font color='red'>start with drawing. some case studies </font>
#
# 1) Ininiate a stack[]
#
# 2) ininiate a dictionary to store the open/close pairs to check match
#
# 3) a pointer i for s
#
# 4) loop through s:
#
# > if it's in dictionary(open) , add s[i]
#
# > if stack is empty but it's not in dictionary (close), return false
#
# > if stack is not empty and not in dictionaary (close). check if s[i] vs stack.top() match
#
# > > if yes, pop top, move pointer
#
# > > if not, return false
#
# 4) check len(stack)

# %% [markdown]
# # Thoughts 4/1/2026: <font color='red'>WRONG</font>
#
# Brute force O(N2)
#
# Solutinon1 stack
#
# There are two type of brackets- open and closed. The most recent open bracket(e.g. '(') must match the first added close bracket(e.g. ')'). Think in example 2 and 5. Think more in flow ranther in index.
#
# Algorithm:
#
# 1. initiate a stack=[]
#
# 2. initiate a pointer i for s
#
# 3. a dictionary to store open/close pairs: key=open, value=closed
#
# 4. while i <=len(s)-1:
#
#    - if stack is emty: add s[i] to stack, move pointer in s
#
#    - if not empty:
#
#        - if s[i] is one of the open bracket (in dictionary.keys()):
#
#          - add to the stack, move pointer in s
#
#        - else then it is a closed bracket, does it match stack top using dictionary pair:
#
#             - if so: pop stack top, keeping moving the pointer i+=1
#
#             - if not, return false
#
# return True if we can get to this step? (but for one element: have to be checked in the beginning)
#
# or
#
# ruturn true if myStack is empty
#
# fails ']]'

# %%
from typing import List

def valid_p(s: str)-> bool:
    if not s: # check if empty
        return False
    
    my_stack=[]
    my_dict={'(':')', '[':']','{':'}'}

    i=0

    for i in range(len(s)):
        if s[i] in my_dict:
            my_stack.append(s[i])
        elif s[i] not in my_dict and len(my_stack)==0:
            return False
        else:
            if s[i]==my_dict[my_stack[-1]]: # check if s[i] matches stack's top's pair
                my_stack.pop() # remove last element
            else:
                return False
    if len(my_stack)!=0:
        return False
    else:
        return True

# %%
print(valid_p('()[]{}'))
print(valid_p('([][]{}'))
print(valid_p(']]'))
# Out:
# True
# False
# False

# %% [markdown]
# # 739 Daily temp

# %% [markdown]
# Given an array of integers temperatures represents the daily temperatures, return an array answer such that answer[i] is the number of days you have to wait after the ith day to get a warmer temperature. If there is no future day for which this is possible, keep answer[i] == 0 instead.
#
#
#
# Example 1:
#
# Input: temperatures = [73,74,75,71,69,72,76,73]
# Output: [1,1,4,2,1,1,0,0]
# Example 2:
#
# Input: temperatures = [30,40,50,60]
# Output: [1,1,1,0]
# Example 3:
#
# Input: temperatures = [30,60,90]
# Output: [1,1,0]
#
#
# Constraints:
#
# 1 <= temperatures.length <= 105
# 30 <= temperatures[i] <= 100

# %% [markdown]
# Thoughts: time O(N) space O(N)
#
# 1) initiate a stack and a pointer
#
# 2) for i, e in enumerate string:
#
# > create a pair (e,i) [0]-> e [1]->i
#
# > if stack is empty: add s[i] to stack
#
# > check s[i] > stack.top():
# > > if yes, pop top e ; save top's index: i to results
# > > continute to check till s[i] <= stack.top or stack is empty
#
# > > if no, add s[i] to stack top
#
# results ={i:min_warmer_index,....}
#
# warm_list=[]
#
# 3) for all i in list:
#     if i in restuls:
#         append the difference (results[i]-i) to warm_list
#     else:
#         results[i]=0

# %%
from typing import List

def warm_tem(tem_list:List[int])->List[int]:

    # check if empty
    if not tem_list:
        return []
    
    my_stack=[]
    i=0
    results={} # to remember i and their min warm temp's index

    for i,e in enumerate(tem_list):
        pair=(e,i) # a tuple to remember the index

        if not my_stack: # if stack is empty, add s[i] on top
            my_stack.append(pair)

        else: # if not, compare
            while tem_list[i] > my_stack[-1][0]: # if it is warmer and stack is not empty. 
                results[my_stack[-1][1]]=i # save top's index as key and warmer's index as value
                my_stack.pop()
                if not my_stack: # if nothing left after pop, we don't continue
                    break
            
            my_stack.append(pair) # till stack is empty or no longer warmer than previous, add to top
    warm_list=[]

    for i in range(len(tem_list)):
        if i in results:
            warm_list.append(results[i]-i)
        else:
            warm_list.append(0)
    return warm_list 


print(warm_tem([73,74,75,71,69,72,76,73]))
# Out:
# [1, 1, 4, 2, 1, 1, 0, 0]

# %% [markdown]
# # Evaluate Reverse Polish Notation

# %% [markdown]
# You are given an array of strings tokens that represents an arithmetic expression in a Reverse Polish Notation.
#
# Evaluate the expression. Return an integer that represents the value of the expression.
#
# Note that:
#
# The valid operators are '+', '-', '*', and '/'.
# Each operand may be an integer or another expression.
# The division between two integers always truncates toward zero.
# There will not be any division by zero.
# The input represents a valid arithmetic expression in a reverse polish notation.
# The answer and all the intermediate calculations can be represented in a 32-bit integer.
#
#
# Example 1:
#
# Input: tokens = ["2","1","+","3","*"]
# Output: 9
# Explanation: ((2 + 1) * 3) = 9
# Example 2:
#
# Input: tokens = ["4","13","5","/","+"]
# Output: 6
# Explanation: (4 + (13 / 5)) = 6
# Example 3:
#
# Input: tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]
# Output: 22
# Explanation: ((10 * (6 / ((9 + 3) * -11))) + 17) + 5
# = ((10 * (6 / (12 * -11))) + 17) + 5
# = ((10 * (6 / -132)) + 17) + 5
# = ((10 * 0) + 17) + 5
# = (0 + 17) + 5
# = 17 + 5
# = 22

# %% [markdown]
# # Thoughts
#
# empty (needs check); valid (no need)
#
# Stack always operate on top 2 elements of stack
#
# 1. initiate a stack
#
# iterate nums list
#
# 2. if nums[i] is a number: append to stack (is numeric does not work with negative number; isdigit does not work) solution use a flag and try/except
#
# - if nums[i]=="+":
#
#          r=stack.pop()+stack.pop()
#
#         stack.append(r)
#
# - if nums[i]=="-": # - and / pay attention to order
#
#         a,b=stack.pop(),stack.pop()
#
#         stack.append(b-a)
#
# - if nums[i] =="*"
#
#         stack.append(multiply result)
#
# - if nums[i] =='/'
#
#         a,b=stack.pop(),stack.pop()
#
#         stack.append(int(b/a))
#
#  return stack

# %%
from typing import List
def check(nums:List[str])->int:

    # check empty
    if not nums:
        return 0
    
    my_stack=[]

    for num in nums:
        # if digit, append
        is_num=False

        try:
            int(num)
            is_num=True
            my_stack.append(int(num))
        except ValueError:
            pass

        if not is_num:
            if num=="+":
                my_stack.append(int(my_stack.pop())+int(my_stack.pop()))
            elif num=='-':
                a,b=int(my_stack.pop()),int(my_stack.pop())
                my_stack.append(b-a)

            elif num=="*":
                my_stack.append(int(my_stack.pop())*int(my_stack.pop()))

            else:
                a,b=int(my_stack.pop()),int(my_stack.pop())
                my_stack.append(int(b/a))
    return my_stack[0]

        
print(check( ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]))
print(check( ["4","13","5","/","+"]))
# Out:
# 22
# 6
